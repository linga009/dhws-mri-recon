# %% [markdown]
# # SHARC-MRI (DHWS-MRI-Efficient) Training
# This notebook trains the Spectral-Hash Accelerated Reconstruction Cascade (SHARC) on Google Colab.
# It mounts your Google Drive, installs dependencies, and runs the script natively on the Colab GPU.

# %%
# 1. Check GPU allocation (A100, V100, or T4)
# !nvidia-smi

# %%
# 2. Mount Google Drive to access your code and save checkpoints
from google.colab import drive
drive.mount('/content/drive')

# %%
# 3. Install required libraries
# HuggingFace 'datasets' is needed for the fastMRI dataloader fallback.
# !pip install datasets

# %%
import os

# 4. Navigate to your DHWS directory inside Google Drive
WORK_DIR = '/content/drive/MyDrive/DHWS'
os.makedirs(WORK_DIR, exist_ok=True)
os.chdir(WORK_DIR)

print(f"Current working directory: {os.getcwd()}")
# !ls -l dhws_mri_efficient.py  # Verify the script is present

# %%
# 5. Start the training run!
# !python dhws_mri_efficient.py
